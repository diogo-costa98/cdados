# %%
import pandas as pd
import matplotlib.pyplot as plt
import ds_functions as ds

data_heart_failure = pd.read_csv('datasets/heart_failure_clinical_records_dataset_upgraded.csv', parse_dates=True, infer_datetime_format=True)
data_oral_toxicity = pd.read_csv('datasets/qsar_oral_toxicity_upgraded.csv', parse_dates=True, infer_datetime_format=True)

values_heart_failure = {'nr records': data_heart_failure.shape[0], 'nr variables': data_heart_failure.shape[1]}
values_oral_toxicity = {'nr records': data_oral_toxicity.shape[0], 'nr variables': data_oral_toxicity.shape[1]}

print('Heart_failure :', values_heart_failure)
print('Oral_toxicity :' ,values_oral_toxicity)
# Out:
# Heart_failure : {'nr records': 299, 'nr variables': 13}
# Oral_toxicity : {'nr records': 8992, 'nr variables': 1025}

# %% [markdown]
# #### Histograms for Heart_failure

# %%
variables = data_heart_failure.select_dtypes(include='number').columns
rows, cols = ds.choose_grid(len(variables))
fig, axs = plt.subplots(rows, cols, figsize=(cols*ds.HEIGHT, rows*ds.HEIGHT))
i, j = 0, 0
for n in range(len(variables)):
    axs[i, j].set_title('Histogram for %s'%variables[n])
    axs[i, j].set_xlabel(variables[n])
    axs[i, j].set_ylabel('nr records')
    axs[i, j].hist(data[variables[n]].values, bins=100)
    i, j = (i + 1, 0) if (n+1) % cols == 0 else (i, j + 1)
plt.show()

# %% [markdown]
# #### Histograms for Oral_toxicity

# %%
variables = data_oral_toxicity.select_dtypes(include='number').columns
rows, cols = ds.choose_grid(len(variables))
print(len(rows))
print(len(cols))
fig, axs = plt.subplots(rows, cols, figsize=(cols*ds.HEIGHT, rows*ds.HEIGHT))
i, j = 0, 0
for n in range(len(variables)):
    axs[i, j].set_title('Histogram for %s'%variables[n])
    axs[i, j].set_xlabel(variables[n])
    axs[i, j].set_ylabel('nr records')
    axs[i, j].hist(data[variables[n]].values, bins=100)
    i, j = (i + 1, 0) if (n+1) % cols == 0 else (i, j + 1)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-30-57cd80170430> in <module>
#       1 variables = data_oral_toxicity.select_dtypes(include='number').columns
#       2 rows, cols = ds.choose_grid(len(variables))
# ----> 3 fig, axs = plt.subplots(rows, cols, figsize=(cols*ds.HEIGHT, rows*ds.HEIGHT))
#       4 i, j = 0, 0
#       5 for n in range(len(variables)):
#
# ~/anaconda3/lib/python3.8/site-packages/matplotlib/cbook/deprecation.py in wrapper(*args, **kwargs)
#     449                 "parameter will become keyword-only %(removal)s.",
#     450                 name=name, obj_type=f"parameter of {func.__name__}()")
# --> 451         return func(*args, **kwargs)
#     452
#     453     return wrapper
#
# ~/anaconda3/lib/python3.8/site-packages/matplotlib/pyplot.py in subplots(nrows, ncols, sharex, sharey, squeeze, subplot_kw, gridspec_kw, **fig_kw)
# ...
